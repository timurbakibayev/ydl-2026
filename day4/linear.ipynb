# %%
import pandas as pd

# %%
df = pd.read_excel("cars.xlsx")

# %%
df
# Out:
#        Make     Model  Year    Gear  Engine condition     Price
# 0    Toyota     Camry  2018  manual     2.0        ok   9000000
# 1    Toyota     Camry  2020    auto     2.0        ok  13000000
# 2    Toyota        LC  2015  manual     4.0        ok  12000000
# 3    Toyota        LC  2000    auto     4.5        ok   7000000
# 4  Mercedes      E320  2026    auto     3.2        ok  30000000
# 5       BMW       750  2018  manual     5.0    broken   2500000
# 6       BMW       325  2025  manual     2.5        ok  35000000
# 7    Subaru  Forester  2020    auto     2.0        ok  12000000
# 8     Volvo       850  1985  manual     1.8        ok   3000000

# %%
df.head()
# Out:
#        Make  Model  Year    Gear  Engine condition     Price
# 0    Toyota  Camry  2018  manual     2.0        ok   9000000
# 1    Toyota  Camry  2020    auto     2.0        ok  13000000
# 2    Toyota     LC  2015  manual     4.0        ok  12000000
# 3    Toyota     LC  2000    auto     4.5        ok   7000000
# 4  Mercedes   E320  2026    auto     3.2        ok  30000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Make       9 non-null      object
#  1   Model      9 non-null      object
#  2   Year       9 non-null      int64
#  3   Gear       9 non-null      object
#  4   Engine     9 non-null      float64
#  5   condition  9 non-null      object
#  6   Price      9 non-null      int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 632.0+ bytes

# %%
df["is_toyota"] = df["Make"] == "Toyota"
df["is_mercedes"] = df["Make"] == "Mercedes"

# %%
df
# Out:
#        Make     Model  Year    Gear  Engine condition     Price  is_toyota
# 0    Toyota     Camry  2018  manual     2.0        ok   9000000       True  \
# 1    Toyota     Camry  2020    auto     2.0        ok  13000000       True
# 2    Toyota        LC  2015  manual     4.0        ok  12000000       True
# 3    Toyota        LC  2000    auto     4.5        ok   7000000       True
# 4  Mercedes      E320  2026    auto     3.2        ok  30000000      False
# 5       BMW       750  2018  manual     5.0    broken   2500000      False
# 6       BMW       325  2025  manual     2.5        ok  35000000      False
# 7    Subaru  Forester  2020    auto     2.0        ok  12000000      False
# 8     Volvo       850  1985  manual     1.8        ok   3000000      False
#
#    is_mercedes
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# 5        False
# 6        False
# 7        False
# 8        False

# %%
for make in df["Make"].unique():
    df[make] = df["Make"] == make

# %%
df.drop("is_mercedes", axis=1, inplace=True)
# df = df.drop("is_toyota", axis=1)

# %%
df
# Out:
#        Make     Model  Year    Gear  Engine condition     Price  Toyota
# 0    Toyota     Camry  2018  manual     2.0        ok   9000000    True  \
# 1    Toyota     Camry  2020    auto     2.0        ok  13000000    True
# 2    Toyota        LC  2015  manual     4.0        ok  12000000    True
# 3    Toyota        LC  2000    auto     4.5        ok   7000000    True
# 4  Mercedes      E320  2026    auto     3.2        ok  30000000   False
# 5       BMW       750  2018  manual     5.0    broken   2500000   False
# 6       BMW       325  2025  manual     2.5        ok  35000000   False
# 7    Subaru  Forester  2020    auto     2.0        ok  12000000   False
# 8     Volvo       850  1985  manual     1.8        ok   3000000   False
#
#    Mercedes    BMW  Subaru  Volvo
# 0     False  False   False  False
# 1     False  False   False  False
# 2     False  False   False  False
# 3     False  False   False  False
# 4      True  False   False  False
# 5     False   True   False  False
# ...

# %%
for make in df["Make"].unique():
    df.drop(make, axis=1, inplace=True)

# %%
df = pd.get_dummies(df, columns=["Make"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = pd.get_dummies(df, columns=["Make"])
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/reshape/encoding.py:158, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     156     raise TypeError("Input must be a list-like for parameter `columns`")
#     157 else:
# --> 158     data_to_encode = data[columns]
#     160 # validate prefixes and separator to avoid silently dropping cols
#     161 def check_len(item, name):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
# ...

# %%
df = pd.get_dummies(df, columns=["condition"])

# %%
df = pd.get_dummies(df, columns=["Gear"])

# %%
df
# Out:
#       Model  Year  Engine     Price  Make_BMW  Make_Mercedes  Make_Subaru
# 0     Camry  2018     2.0   9000000     False          False        False  \
# 1     Camry  2020     2.0  13000000     False          False        False
# 2        LC  2015     4.0  12000000     False          False        False
# 3        LC  2000     4.5   7000000     False          False        False
# 4      E320  2026     3.2  30000000     False           True        False
# 5       750  2018     5.0   2500000      True          False        False
# 6       325  2025     2.5  35000000      True          False        False
# 7  Forester  2020     2.0  12000000     False          False         True
# 8       850  1985     1.8   3000000     False          False        False
#
#    Make_Toyota  Make_Volvo  condition_broken  condition_ok  Gear_auto
# 0         True       False             False          True      False  \
# 1         True       False             False          True       True
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
X = df.drop(["Price", "Model"], axis=1)
y = df["Price"]

# %%
X
# Out:
#    Year  Engine  Make_BMW  Make_Mercedes  Make_Subaru  Make_Toyota
# 0  2018     2.0     False          False        False         True  \
# 1  2020     2.0     False          False        False         True
# 2  2015     4.0     False          False        False         True
# 3  2000     4.5     False          False        False         True
# 4  2026     3.2     False           True        False        False
# 5  2018     5.0      True          False        False        False
# 6  2025     2.5      True          False        False        False
# 7  2020     2.0     False          False         True        False
# 8  1985     1.8     False          False        False        False
#
#    Make_Volvo  condition_broken  condition_ok  Gear_auto  Gear_manual
# 0       False             False          True      False         True
# 1       False             False          True       True        False
# 2       False             False          True      False         True
# ...

# %%
y
# Out:
# 0     9000000
# 1    13000000
# 2    12000000
# 3     7000000
# 4    30000000
# 5     2500000
# 6    35000000
# 7    12000000
# 8     3000000
# Name: Price, dtype: int64

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([   600000.        ,   2399999.99999999,  11720000.00000001,
#          1640000.00000001,  -9879999.99999998,  -8879999.99999999,
#          5399999.99999996, -17149999.99999999,  17149999.99999998,
#          1400000.        ,  -1400000.        ])

# %%
model.intercept_
# Out:
# -1213469999.999992

# %%
df["guess"] = model.predict(X)

# %%
df
# Out:
#       Model  Year  Engine     Price  Make_BMW  Make_Mercedes  Make_Subaru
# 0     Camry  2018     2.0   9000000     False          False        False  \
# 1     Camry  2020     2.0  13000000     False          False        False
# 2        LC  2015     4.0  12000000     False          False        False
# 3        LC  2000     4.5   7000000     False          False        False
# 4      E320  2026     3.2  30000000     False           True        False
# 5       750  2018     5.0   2500000      True          False        False
# 6       325  2025     2.5  35000000      True          False        False
# 7  Forester  2020     2.0  12000000     False          False         True
# 8       850  1985     1.8   3000000     False          False        False
#
#    Make_Toyota  Make_Volvo  condition_broken  condition_ok  Gear_auto
# 0         True       False             False          True      False  \
# 1         True       False             False          True       True
# ...

# %%
df = pd.DataFrame({
    "father": [170, 180, 175, 165, 160, 175],
    "mother": [160, 175, 180, 170, 160, 190],
    "child":  [173, 190, 191, 175, 165, 193],
})

# %%
df
# Out:
#    father  mother  child
# 0     170     160    173
# 1     180     175    190
# 2     175     180    191
# 3     165     170    175
# 4     160     160    165
# 5     175     190    193

# %%
X = df[["father", "mother"]]
y = df["child"]

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
df["ml"] = model.predict(X)

# %%
df
# Out:
#    father  mother  child          ml
# 0     170     160    173  173.607646
# 1     180     175    190  190.378270
# 2     175     180    191  188.839034
# 3     165     170    175  174.806841
# 4     160     160    165  165.052314
# 5     175     190    193  194.315895

# %%
model.coef_
# Out:
# array([0.8555332 , 0.54768612])

# %%
model.intercept_
# Out:
# -59.462776659959786

# %%
180*0.855 + 175*0.5476 - 59.46277
# Out:
# 190.26723

# %%
df_test = pd.DataFrame({
    "father": [180, 190, 205, 175, 175, 170],
    "mother": [170, 178, 180, 180, 190, 190],
})

# %%
childred = model.predict(df_test)

# %%
df_test["child"] = childred

# %%
df_test
# Out:
#    father  mother       child
# 0     180     170  187.639839
# 1     190     178  200.576660
# 2     205     180  214.505030
# 3     175     180  188.839034
# 4     175     190  194.315895
# 5     170     190  190.038229
